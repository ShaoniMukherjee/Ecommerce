# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
aisles = pd.read_csv('aisles.csv')

departments = pd.read_csv('departments.csv')

orders = pd.read_csv('orders.csv', 
                 dtype={
                        'order_id': np.int32,
                        'user_id': np.int64,
                        'eval_set': 'category',
                        'order_number': np.int16,
                        'order_dow': np.int8,
                        'order_hour_of_day': np.int8,
                        'days_since_prior_order': np.float32})

order_products_prior = pd.read_csv('order_products__prior.csv', 
                                 dtype={
                                        'order_id': np.int32,
                                        'product_id': np.uint16,
                                        'add_to_cart_order': np.int16,
                                        'reordered': np.int8})

order_products_train = pd.read_csv('order_products__train.csv', 
                                 dtype={
                                        'order_id': np.int32,
                                        'product_id': np.uint16,
                                        'add_to_cart_order': np.int16,
                                        'reordered': np.int8})
products = pd.read_csv('products.csv')

# %%
aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
aisles['aisle'].nunique()
# Out:
# 134

# %%
departments.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
order_products_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
prior_df = order_products_prior.merge(orders, on = 'order_id',how = 'inner')
prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1         2       28985                  2          1   202279    prior
# 2         2        9327                  3          0   202279    prior
# 3         2       45918                  4          1   202279    prior
# 4         2       30035                  5          0   202279    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order
# 0             3          5                  9                     8.0
# 1             3          5                  9                     8.0
# 2             3          5                  9                     8.0
# 3             3          5                  9                     8.0
# 4             3          5                  9                     8.0

# %%
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
products_detail = products.merge(departments, on = 'department_id', how = 'inner')

# %%
products_detail.head(10)
# Out:
#    product_id                                 product_name  aisle_id  \
# 0           1                   Chocolate Sandwich Cookies        61
# 1          16                Mint Chocolate Flavored Syrup       103
# 2          25      Salted Caramel Lean Protein & Fiber Bar         3
# 3          32                Nacho Cheese White Bean Chips       107
# 4          41  Organic Sourdough Einkorn Crackers Rosemary        78
# 5          56                   Healthy Pop Butter Popcorn        23
# 6          59         Medium Taqueria Style Chipotle Salsa        50
# 7          77            Coconut Chocolate Chip Energy Bar         3
# 8          78            Nutter Butter Cookie Bites Go-Pak        61
# 9          93                  Uncured Cracked Pepper Beef        23
#
#    department_id department
# 0             19     snacks
# 1             19     snacks
# 2             19     snacks
# 3             19     snacks
# 4             19     snacks
# 5             19     snacks
# ...

# %%
products_detail = products_detail.merge(aisles, on = 'aisle_id', how = 'inner')
products_detail.head()
# Out:
#    product_id                                    product_name  aisle_id  \
# 0           1                      Chocolate Sandwich Cookies        61
# 1          78               Nutter Butter Cookie Bites Go-Pak        61
# 2         102                           Danish Butter Cookies        61
# 3         172  Gluten Free All Natural Chocolate Chip Cookies        61
# 4         285                    Mini Nilla Wafers Munch Pack        61
#
#    department_id department          aisle
# 0             19     snacks  cookies cakes
# 1             19     snacks  cookies cakes
# 2             19     snacks  cookies cakes
# 3             19     snacks  cookies cakes
# 4             19     snacks  cookies cakes

# %%
products_detail['department'].nunique()
# Out:
# 21
